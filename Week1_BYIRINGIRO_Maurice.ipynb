# %%
#0.
print("Hello, Big Data!")
# Out:
# Hello, Big Data!

# %%
#1.
#1.1
my_name= "Maurice BYIRINGIRO"
my_age= 35
my_gpa= 12.6
am_i_present = True

print(my_name, type(my_name))
print(my_age, type(my_age))
print(my_gpa, type(my_gpa))
print(am_i_present, type(am_i_present))
# Out:
# Maurice BYIRINGIRO <class 'str'>
# 35 <class 'int'>
# 12.6 <class 'float'>
# True <class 'bool'>

# %%
#1.2
age_text = "21"
age_number = int (age_text) +1
print(age_number)
# Out:
# 22

# %%
#2.
"3" + "4"
# Out:
# '34'

# %%
#Because in python the addition of string become concatination instead of adding value 
#Except the value with float and integers datatype only. that where it should become 7. it requres arithimetic to these all values and proper datatype

# %%
print(f"I'am {my_name},{my_age} Years old,Studing at Auca")
# Out:
# I'am Maurice BYIRINGIRO,35 Years old,Studing at Auca

# %%
course = "Big Data Analytics"
#a.
print(course.upper())
#b.
print(course.len())
# Out:
# BIG DATA ANALYTICS
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 5
#       3 print(course.upper())
#       4 #b.
# ----> 5 print(course.len())
#
# AttributeError: 'str' object has no attribute 'len'

# %%
print(len(course))

# %%
#c.
print(course[0:3])

# %%
score = [72, 85, 91, 64, 78]
print(score[0])

# %%
print(score[-1])

# %%
print(len(score))

# %%
print(sum(score) / len(score))

# %%
print(max(score))

# %%
print(min(score))

# %%
score.append(66)

# %%
score[3] = 66

# %%
print(score)

# %%
print(sum(score) / len(score))

# %%
    me = {"name": my_name,"age": my_age,"program":"Software Engineering", "District": "Kicukiro"}
    print(me[program])

# %%
print(me["program"])

# %%
me["score"] = 80

# %%
me["age"] + 1

# %%
print(me.keys())

# %%
print(me)

# %%
#5.
students = [
    {"id": "AUCA001", "name": "Aline Uwase", "age": 21, "gender": "F", "program": "Information Systems", "district": "Gasabo", "att": 92, "score": 85},
    {"id": "AUCA002", "name": "Eric Niyonzima", "age": 23, "gender": "M", "program": "Software Engineering", "district": "Kicukiro", "att": 88, "score": 78},
    {"id": "AUCA003", "name": "Diane Mukamana", "age": 20, "gender": "F", "program": "Information Systems", "district": "Nyarugenge", "att": 95, "score": 91},
    {"id": "AUCA004", "name": "Jean Bosco Habimana", "age": 24, "gender": "M", "program": "Networking", "district": "Gasabo", "att": 70, "score": 64},
    {"id": "AUCA005", "name": "Clarisse Ingabire", "age": 22, "gender": "F", "program": "Accounting", "district": "Musanze", "att": 85, "score": 72},
    {"id": "AUCA006", "name": "Patrick Mugisha", "age": 21, "gender": "M", "program": "Software Engineering", "district": "Huye", "att": 90, "score": 83},
    {"id": "AUCA007", "name": "Sandrine Umutoni", "age": 19, "gender": "F", "program": "Information Systems", "district": "Kicukiro", "att": 97, "score": 94},
    {"id": "AUCA008", "name": "Emmanuel Nsengiyumva", "age": 25, "gender": "M", "program": "Networking", "district": "Rubavu", "att": 65, "score": 58},
    {"id": "AUCA009", "name": "Grace Uwimana", "age": 20, "gender": "F", "program": "Accounting", "district": "Gasabo", "att": 82, "score": 76},
    {"id": "AUCA010", "name": "Yves Ndayisenga", "age": 22, "gender": "M", "program": "Software Engineering", "district": "Nyarugenge", "att": 78, "score": 69},
    {"id": "AUCA011", "name": "Josiane Mukeshimana", "age": 21, "gender": "F", "program": "Information Systems", "district": "Muhanga", "att": 93, "score": 88},
    {"id": "AUCA012", "name": "Claude Iradukunda", "age": 23, "gender": "M", "program": "Networking", "district": "Gasabo", "att": 75, "score": 66},
    {"id": "AUCA013", "name": "Beata Nyirahabimana", "age": 24, "gender": "F", "program": "Accounting", "district": "Nyamagabe", "att": 89, "score": 81},
    {"id": "AUCA014", "name": "Olivier Twagirimana", "age": 20, "gender": "M", "program": "Software Engineering", "district": "Kicukiro", "att": 96, "score": 90},
    {"id": "AUCA015", "name": "Chantal Uwera", "age": 22, "gender": "F", "program": "Information Systems", "district": "Rusizi", "att": 68, "score": 61},
    {"id": "AUCA016", "name": "Fabrice Byiringiro", "age": 21, "gender": "M", "program": "Networking", "district": "Musanze", "att": 84, "score": 74},
    {"id": "AUCA017", "name": "Solange Ishimwe", "age": 19, "gender": "F", "program": "Software Engineering", "district": "Gasabo", "att": 91, "score": 87},
    {"id": "AUCA018", "name": "David Hakizimana", "age": 25, "gender": "M", "program": "Accounting", "district": "Nyagatare", "att": 72, "score": 55},
    {"id": "AUCA019", "name": "Immaculee Uwamahoro", "age": 23, "gender": "F", "program": "Information Systems", "district": "Kicukiro", "att": 87, "score": 79},
    {"id": "AUCA020", "name": "Samuel Rukundo", "age": 20, "gender": "M", "program": "Networking", "district": "Nyarugenge", "att": 94, "score": 92},
]

# %%
#a.
print(f"number of students:{len(students)}")

# %%
#b.
names =[s["name"] for s in students]

# %%
#c.
all_scores =[s["score"] for s in students]

# %%
#d.
districts =[s["district"] for s in students]

# %%
print(f"class average score :{round(sum(all_scores)/len(all_scores),1)}")

# %%
print(f"Highest: {max(all_scores)}")

# %%
print(f"lowest: {min(all_scores)}")

# %%
print(f"Range :{max(all_scores)} - {min(all_scores)}")

# %%
#5.2
#a.
print(students[0])

# %%
#b.
print(students[-1])

# %%
s = students[6]
print(f"{s['name']} from {s['district']} studies {s['program']} and scored {s['score']}.")

# %%
## 5.3
#a.
print(districts.count("Gasabo"))

# %%
#b.
print(districts.count("Kicukiro"))

# %%
#c.
print(districts.count("Musanze"))

# %%
#5.4
top_score = max(all_scores)
top_index = all_scores.index(top_score)
top_name = names[top_index]
print(f"the top student is {top_name} with a score of {top_score}.")

# %%
#Bonus
low_score = min(all_scores)
low_index = all_scores.index(low_score)
low_name = names[low_index]
print(f"the lowest student is {low_name} with a score of {low_score}")

# %%
print(f"{top_name}'s attendance : {students[top_index]['att']}%")

# %%
print(f"{low_name}'s attendance : {students[low_index]['att']}%")

# %%
#6
This dataset is not Big Data.
it only has 20 records, which is far below the Volume threshold typically associated with Big Data. 
It also lacks Velocity, since it's a static snapshot rather than continuously generated data

#supprise and confusion
This one is genuinely personal — think back over the lab. Some honest options based on what we worked through together:

The "3" + "4" = "34" result (string concatenation vs. numeric addition) often surprises people.
List comprehensions ([s["name"] for s in students]) can feel confusing the first time you see them.
Realizing students, names, all_scores, and districts are all "linked" by position (index) can be a genuine lightbulb moment.
