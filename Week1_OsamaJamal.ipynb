# %%
print ("Hello Big Data!")
# Out:
# Hello Big Data!

# %%
my_name = "Osama"
my_age = 25
my_gpa = 3.6
am_i_present = True

print (my_name, type(my_name))
print (my_age, type(my_age))
print (my_gpa, type(my_gpa))
print (am_i_present, type(am_i_present))
# Out:
# Osama <class 'str'>
# 25 <class 'int'>
# 3.6 <class 'float'>
# True <class 'bool'>

# %%
age_text = "21"
age = int(age_text)

age = age + 1

print(age)
# Out:
# 22

# %%
print("3" + "4")
# Out:
# 34

# %%
my_name = "Osama"
my_age = 25

print (f"I am {my_name}, {my_age} years old , studying at AUCA.")
# Out:
# I am Osama, 25 years old , studying at AUCA.

# %%
course = "Big Data Analytics"

print (course.upper())
print (len(course))
print (course[0:3])
# Out:
# BIG DATA ANALYTICS
# 18
# Big

# %%
scores = [72, 85, 91, 64, 78]

print("First score:", scores[0])
print("Last score:", scores[-1])
print("Number of scores:", len(scores))
print("Average:", sum(scores) / len(scores))
print("Highest score:", max(scores))
print("Lowest score:", min(scores))
# Out:
# First score: 72
# Last score: 78
# Number of scores: 5
# Average: 78.0
# Highest score: 91
# Lowest score: 64

# %%
scores.append(88)
scores[3] = 66

print("Updated scores:", scores)
print("New average:", sum(scores) / len(scores))
# Out:
# Updated scores: [72, 85, 91, 66, 78, 88]
# New average: 80.0

# %%
me = {
    "name" : "Osama",
    "age" : 25,
    "program" : "software engineering",
    "district" : "Gasabo"
}

print (me["program"])
# Out:
# software engineering

# %%
me["score"] = 90
me["age"] = me["age"] + 1

print (me.keys())
print (me)
# Out:
# dict_keys(['name', 'age', 'program', 'district', 'score'])
# {'name': 'Osama', 'age': 26, 'program': 'software engineering', 'district': 'Gasabo', 'score': 90}

# %%
students = [
    {"id": "AUCA001", "name": "Aline Uwase", "age": 21, "gender": "F", "program": "Information Systems", "district": "Gasabo", "attendance_pct": 92, "score": 85},
    {"id": "AUCA002", "name": "Eric Niyonzima", "age": 23, "gender": "M", "program": "Software Engineering", "district": "Kicukiro", "attendance_pct": 88, "score": 78},
    {"id": "AUCA003", "name": "Diane Mukamana", "age": 20, "gender": "F", "program": "Information Systems", "district": "Nyarugenge", "attendance_pct": 95, "score": 91},
    {"id": "AUCA004", "name": "Jean Bosco Habimana", "age": 24, "gender": "M", "program": "Networking", "district": "Gasabo", "attendance_pct": 70, "score": 64},
    {"id": "AUCA005", "name": "Clarisse Ingabire", "age": 22, "gender": "F", "program": "Accounting", "district": "Musanze", "attendance_pct": 85, "score": 72},
    {"id": "AUCA006", "name": "Patrick Mugisha", "age": 21, "gender": "M", "program": "Software Engineering", "district": "Huye", "attendance_pct": 90, "score": 83},
    {"id": "AUCA007", "name": "Sandrine Umutoni", "age": 19, "gender": "F", "program": "Information Systems", "district": "Kicukiro", "attendance_pct": 97, "score": 94},
    {"id": "AUCA008", "name": "Emmanuel Nsengiyumva", "age": 25, "gender": "M", "program": "Networking", "district": "Rubavu", "attendance_pct": 65, "score": 58},
    {"id": "AUCA009", "name": "Grace Uwimana", "age": 20, "gender": "F", "program": "Accounting", "district": "Gasabo", "attendance_pct": 82, "score": 76},
    {"id": "AUCA010", "name": "Yves Ndayisenga", "age": 22, "gender": "M", "program": "Software Engineering", "district": "Nyarugenge", "attendance_pct": 78, "score": 69},
    {"id": "AUCA011", "name": "Josiane Mukeshimana", "age": 21, "gender": "F", "program": "Information Systems", "district": "Muhanga", "attendance_pct": 93, "score": 88},
    {"id": "AUCA012", "name": "Claude Iradukunda", "age": 23, "gender": "M", "program": "Networking", "district": "Gasabo", "attendance_pct": 75, "score": 66},
    {"id": "AUCA013", "name": "Beata Nyirahabimana", "age": 24, "gender": "F", "program": "Accounting", "district": "Nyamagabe", "attendance_pct": 89, "score": 81},
    {"id": "AUCA014", "name": "Olivier Twagirimana", "age": 20, "gender": "M", "program": "Software Engineering", "district": "Kicukiro", "attendance_pct": 96, "score": 90},
    {"id": "AUCA015", "name": "Chantal Uwera", "age": 22, "gender": "F", "program": "Information Systems", "district": "Rusizi", "attendance_pct": 68, "score": 61},
    {"id": "AUCA016", "name": "Fabrice Byiringiro", "age": 21, "gender": "M", "program": "Networking", "district": "Musanze", "attendance_pct": 84, "score": 74},
    {"id": "AUCA017", "name": "Solange Ishimwe", "age": 19, "gender": "F", "program": "Software Engineering", "district": "Gasabo", "attendance_pct": 91, "score": 87},
    {"id": "AUCA018", "name": "David Hakizimana", "age": 25, "gender": "M", "program": "Accounting", "district": "Nyagatare", "attendance_pct": 72, "score": 55},
    {"id": "AUCA019", "name": "Immaculee Uwamahoro", "age": 23, "gender": "F", "program": "Information Systems", "district": "Kicukiro", "attendance_pct": 87, "score": 79},
    {"id": "AUCA020", "name": "Samuel Rukundo", "age": 20, "gender": "M", "program": "Networking", "district": "Nyarugenge", "attendance_pct": 94, "score": 92}
]

# %%
print(len(students))
# Out:
# 20

# %%
names = [s["name"] for s in students]
all_scores = [s["score"] for s in students]
districts = [s["district"] for s in students]

# %%
names = [s["name"] for s in students]
all_scores = [s["score"] for s in students]
districts = [s["district"] for s in students]

# %%
print (len(names))
print (len(all_scores))
print (len(districts))
# Out:
# 20
# 20
# 20

# %%
print(f"Number of students: {len(students)}")
print(f"Class average score: {round(sum(all_scores) / len(all_scores), 1)}")
print(f"Highest score: {max(all_scores)}")
print(f"Lowest score: {min(all_scores)}")
print(f"Score range: {max(all_scores) - min(all_scores)}")
# Out:
# Number of students: 20
# Class average score: 77.2
# Highest score: 94
# Lowest score: 55
# Score range: 39

# %%
print("First student:", students[0])
print("Last student:", students[-1])

student = students[6]

print(f"{student['name']} from {student['district']} studies {student['program']} and scored {student['score']}.")
# Out:
# First student: {'id': 'AUCA001', 'name': 'Aline Uwase', 'age': 21, 'gender': 'F', 'program': 'Information Systems', 'district': 'Gasabo', 'attendance_pct': 92, 'score': 85}
# Last student: {'id': 'AUCA020', 'name': 'Samuel Rukundo', 'age': 20, 'gender': 'M', 'program': 'Networking', 'district': 'Nyarugenge', 'attendance_pct': 94, 'score': 92}
# Sandrine Umutoni from Kicukiro studies Information Systems and scored 94.

# %%
print ("Gasabo:", districts.count("Gasabo"))
print("Kicukiro:", districts.count("Kicukiro"))
print ("Musanze:", districts.count("Musanze"))
# Out:
# Gasabo: 5
# Kicukiro: 4
# Musanze: 2

# %%
top_score = max(all_scores)
top_position = all_scores.index(top_score)
top_name = names[top_position]

print(f"The top student is {top_name} with a score of {top_score}.")
# Out:
# The top student is Sandrine Umutoni with a score of 94.

# %%
lowest_score = min(all_scores)
lowest_position = all_scores.index(lowest_score)
lowest_name = names[lowest_position]

print(f"The lowest student is {lowest_name} with a score of {lowest_score}.")
# Out:
# The lowest student is David Hakizimana with a score of 55.

# %%
top_student = students[top_position]
lowest_student = students[lowest_position]

print(f"Top student: {top_student['name']} - Score: {top_student['score']} - Attendance: {top_student['attendance_pct']}%")
print(f"Lowest student: {lowest_student['name']} - Score: {lowest_student['score']} - Attendance: {lowest_student['attendance_pct']}%")
# Out:
# Top student: Sandrine Umutoni - Score: 94 - Attendance: 97%
# Lowest student: David Hakizimana - Score: 55 - Attendance: 72%
