# %% [markdown]
# ## Part 0

# %%
print("Hello, Big Data!")
# Out:
# Hello, Big Data!

# %% [markdown]
# ## Part 1

# %% [markdown]
# ## part1.1

# %%
my_name = "Doris Akimana"
my_age = 23
my_gpa = 3.8
am_i_present = True

print(my_name, type(my_name))
print(my_age, type(my_age))
print(my_gpa, type(my_gpa))
print(am_i_present, type(am_i_present))
# Out:
# Doris Akimana <class 'str'>
# 23 <class 'int'>
# 3.8 <class 'float'>
# True <class 'bool'>

# %% [markdown]
# ## part1.2

# %%
age = "23"
conv_age = int(raw_age)
print(conv_age + 1)
# Out:
# 24

# %% [markdown]
# ## part1.3

# %%
print("3" + "4")
# Out:
# 34

# %% [markdown]
# ## part2

# %%
print(f"I am {my_name}, {my_age} years old, studying at AUCA.")
# Out:
# I am Doris Akimana, 23 years old, studying at AUCA.

# %%
subject = "Big Data Analytics"
print(subject.upper())
print(len(subject))
print(subject[:3])
# Out:
# BIG DATA ANALYTICS
# 18
# Big

# %% [markdown]
# ## Part 3

# %%
qs = [72, 85, 91, 64, 78]

fs, ls = qs[0], qs[-1]
cs = len(qs)
a_s = sum(qs) / cs
ts, bs = max(qs), min(qs)

print(fs, ls, cs, a_s, ts, bs)
# Out:
# 72 78 5 78.0 91 64

# %%
qs += [88]        
qs[3] = 66
print(qs, sum(qs) / len(qs))
# Out:
# [72, 85, 91, 66, 78, 88] 80.0

# %% [markdown]
# ## Part 4

# %%
profile = dict(name="Doris", age=23, program="Software Engineering", district="Kicukiro")
print(profile["program"])
# Out:
# Software Engineering

# %%
profile.update({"score": 78})
profile["age"] += 1
print(list(profile.keys()))
print(profile)
# Out:
# ['name', 'age', 'program', 'district', 'score']
# {'name': 'Doris', 'age': 24, 'program': 'Software Engineering', 'district': 'Kicukiro', 'score': 78}

# %% [markdown]
# ## Student

# %%
students = [
    {"id": "AUCA001", "name": "Aline Uwase", "age": 21, "gender": "F", "program": "Information Systems", "district": "Gasabo", "att": 92, "score": 85},
    {"id": "AUCA002", "name": "Eric Niyonzima", "age": 23, "gender": "M", "program": "Software Engineering", "district": "Kicukiro", "att": 88, "score": 78},
    {"id": "AUCA003", "name": "Diane Mukamana", "age": 20, "gender": "F", "program": "Information Systems", "district": "Nyarugenge", "att": 95, "score": 91},
    {"id": "AUCA004", "name": "Jean Bosco Habimana", "age": 24, "gender": "M", "program": "Networking", "district": "Gasabo", "att": 70, "score": 64},
    {"id": "AUCA005", "name": "Clarisse Ingabire", "age": 22, "gender": "F", "program": "Accounting", "district": "Musanze", "att": 85, "score": 72},
    {"id": "AUCA006", "name": "Patrick Mugisha", "age": 21, "gender": "M", "program": "Software Engineering", "district": "Huye", "att": 90, "score": 83},
    {"id": "AUCA007", "name": "Sandrine Umutoni", "age": 19, "gender": "F", "program": "Information Systems", "district": "Kicukiro", "att": 97, "score": 94},
    {"id": "AUCA008", "name": "Emmanuel Nsengiyumva", "age": 25, "gender": "M", "program": "Networking", "district": "Rubavu", "att": 65, "score": 58},
    {"id": "AUCA009", "name": "Grace Uwimana", "age": 20, "gender": "F", "program": "Accounting", "district": "Gasabo", "att": 82, "score": 76},
    {"id": "AUCA010", "name": "Yves Ndayisenga", "age": 22, "gender": "M", "program": "Software Engineering", "district": "Nyarugenge", "att": 78, "score": 69},
    {"id": "AUCA011", "name": "Josiane Mukeshimana", "age": 21, "gender": "F", "program": "Information Systems", "district": "Muhanga", "att": 93, "score": 88},
    {"id": "AUCA012", "name": "Claude Iradukunda", "age": 23, "gender": "M", "program": "Networking", "district": "Gasabo", "att": 75, "score": 66},
    {"id": "AUCA013", "name": "Beata Nyirahabimana", "age": 24, "gender": "F", "program": "Accounting", "district": "Nyamagabe", "att": 89, "score": 81},
    {"id": "AUCA014", "name": "Olivier Twagirimana", "age": 20, "gender": "M", "program": "Software Engineering", "district": "Kicukiro", "att": 96, "score": 90},
    {"id": "AUCA015", "name": "Chantal Uwera", "age": 22, "gender": "F", "program": "Information Systems", "district": "Rusizi", "att": 68, "score": 61},
    {"id": "AUCA016", "name": "Fabrice Byiringiro", "age": 21, "gender": "M", "program": "Networking", "district": "Musanze", "att": 84, "score": 74},
    {"id": "AUCA017", "name": "Solange Ishimwe", "age": 19, "gender": "F", "program": "Software Engineering", "district": "Gasabo", "att": 91, "score": 87},
    {"id": "AUCA018", "name": "David Hakizimana", "age": 25, "gender": "M", "program": "Accounting", "district": "Nyagatare", "att": 72, "score": 55},
    {"id": "AUCA019", "name": "Immaculee Uwamahoro", "age": 23, "gender": "F", "program": "Information Systems", "district": "Kicukiro", "att": 87, "score": 79},
    {"id": "AUCA020", "name": "Samuel Rukundo", "age": 20, "gender": "M", "program": "Networking", "district": "Nyarugenge", "att": 94, "score": 92},
]

print(len(students))
print(students[0])
names = [s["name"] for s in students]
all_s = [s["score"] for s in students]
districts = [s["district"] for s in students]
# Out:
# 20
# {'id': 'AUCA001', 'name': 'Aline Uwase', 'age': 21, 'gender': 'F', 'program': 'Information Systems', 'district': 'Gasabo', 'att': 92, 'score': 85}

# %% [markdown]
# ## part5

# %%
t_std = len(all_s)
m_s = round(sum(all_s) / t_std, 1)
best, worst = max(all_s), min(all_s)
spread = best - worst

print(f"Class size: {t_std}")
print(f"Average: {m_s}")
print(f"Best: {best} | Worst: {worst}")
print(f"Spread: {spread}")
# Out:
# Class size: 20
# Average: 77.2
# Best: 94 | Worst: 55
# Spread: 39

# %%
print(students[0])
print(students[len(students)-1])

record = students[6]
print(f"{record['name']} from {record['district']} studies {record['program']} and scored {record['score']}.")
# Out:
# {'id': 'AUCA001', 'name': 'Aline Uwase', 'age': 21, 'gender': 'F', 'program': 'Information Systems', 'district': 'Gasabo', 'att': 92, 'score': 85}
# {'id': 'AUCA020', 'name': 'Samuel Rukundo', 'age': 20, 'gender': 'M', 'program': 'Networking', 'district': 'Nyarugenge', 'att': 94, 'score': 92}
# Sandrine Umutoni from Kicukiro studies Information Systems and scored 94.

# %%
gasabo_count = districts.count("Gasabo")
kicukiro_count = districts.count("Kicukiro")
musanze_count = districts.count("Musanze")
print(gasabo_count, kicukiro_count, musanze_count)
# Out:
# 5 4 2

# %%
b_s = max(all_s)
b_idx = all_s.index(b_s)
print(f"The top student is {names[b_idx]} with a score of {b_s}.")

w_s = min(all_s)
w_idx = all_s.index(w_s)
print(f"The lowest-scoring student is {names[w_idx]} with a score of {w_s}.")
print(students[w_idx]["att"])
# Out:
# The top student is Sandrine Umutoni with a score of 94.
# The lowest-scoring student is David Hakizimana with a score of 55.
# 72

# %% [markdown]
# ## Part 6

# %% [raw]
# My section covers the dataset itself. We only have 20 records something we could easily manage in a single Excel sheet, on one page. That means this is not Big Data. It's lacking Volume, because real Big Data needs a much larger scale, with something updating almost every second new data constantly coming in, whether it's text, images, audio, or video. That's why Big Data requires large storage, like terabytes, to keep up with everything being collected. So this dataset does have Value, since we were able to draw useful insights from it, but it doesn't have Volume. Those are the two V's I'll focus on.

# %% [raw]
# The one thing I learned from this assignment is how easy Jupyter Notebook is to work with. It lets you organize your work naturally if you want to write notes or explain what you observed, you just add a markdown cell and write it down; if it's about code, you have a separate cell just for that. It's really convenient that everything stays in one place, and once you've declared a variable or function earlier in the notebook, you can call it directly later on it's still there. It reminds me a bit of coding in something like VS Code, where what you wrote earlier is still accessible as you keep building on it. I'm not yet sure if Python has classes and other structures the way some other languages do, but this was a great first experience seeing how dictionaries, lists, and counters work, and how close Python syntax is to plain English when communicating with the machine.
