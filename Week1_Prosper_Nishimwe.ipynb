# %% [markdown]
# # AUCA — Introduction to Big Data Analytics
# ## Week 1 Lab — Python Foundations
#
# **Student ID:** 28926
# **Name:** Prosper Nishimwe
# **Program:** Software Engineering

# %%
print("Hello, Big Data!")
# Out:
# Hello, Big Data!

# %%
my_name = "Prosper"
my_age = 20
my_gpa = 14.0
am_i_present = True

print(my_name, type(my_name))
print(my_age, type(my_age))
print(my_gpa, type(my_gpa))
print(am_i_present, type(am_i_present))
# Out:
# Prosper <class 'str'>
# 20 <class 'int'>
# 14.0 <class 'float'>
# True <class 'bool'>

# %%
age_text = "21"

age = int(age_text)
age = age + 1

print(age)
# Out:
# 22

# %%
print("3" + "4")
# Out:
# 34

# %%
print(f"I am {my_name}, {my_age} years old, studying at AUCA.")
# Out:
# I am Prosper, 20 years old, studying at AUCA.

# %%
course = "Big Data Analytics"

print(course.upper())
print(len(course))
print(course[0:3])
# Out:
# BIG DATA ANALYTICS
# 18
# Big

# %%
scores = [72, 85, 91, 64, 78]

print("First score:", scores[0])
print("Last score:", scores[-1])
print("Number of scores:", len(scores))
print("Average:", sum(scores) / len(scores))
print("Highest score:", max(scores))
print("Lowest score:", min(scores))
# Out:
# First score: 72
# Last score: 78
# Number of scores: 5
# Average: 78.0
# Highest score: 91
# Lowest score: 64

# %%
scores.append(88)
scores[3] = 66

print("Updated scores:", scores)
print("New average:", sum(scores) / len(scores))
# Out:
# Updated scores: [72, 85, 91, 66, 78, 88]
# New average: 80.0

# %%
me = {
    "name": "Prosper",
    "age": 20,
    "program": "Software Engineering",
    "district": "Gasabo"
}

print(me["program"])
# Out:
# Software Engineering

# %%
me["score"] = 85
me["age"] = me["age"] + 1

print(me.keys())
print(me)
# Out:
# dict_keys(['name', 'age', 'program', 'district', 'score'])
# {'name': 'Prosper', 'age': 21, 'program': 'Software Engineering', 'district': 'Gasabo', 'score': 85}

# %%
students = [
    {"id": "AUCA001", "name": "Aline Uwase", "age": 21, "gender": "F", "program": "Information Systems", "district": "Gasabo", "attendance": 92, "score": 85},
    {"id": "AUCA002", "name": "Eric Niyonzima", "age": 23, "gender": "M", "program": "Software Engineering", "district": "Kicukiro", "attendance": 88, "score": 78},
    {"id": "AUCA003", "name": "Diane Mukamana", "age": 20, "gender": "F", "program": "Information Systems", "district": "Nyarugenge", "attendance": 95, "score": 91},
    {"id": "AUCA004", "name": "Jean Bosco Habimana", "age": 24, "gender": "M", "program": "Networking", "district": "Gasabo", "attendance": 70, "score": 64},
    {"id": "AUCA005", "name": "Clarisse Ingabire", "age": 22, "gender": "F", "program": "Accounting", "district": "Musanze", "attendance": 85, "score": 72},
    {"id": "AUCA006", "name": "Patrick Mugisha", "age": 21, "gender": "M", "program": "Software Engineering", "district": "Huye", "attendance": 90, "score": 83},
    {"id": "AUCA007", "name": "Sandrine Umutoni", "age": 19, "gender": "F", "program": "Information Systems", "district": "Kicukiro", "attendance": 97, "score": 94},
    {"id": "AUCA008", "name": "Emmanuel Nsengiyumva", "age": 25, "gender": "M", "program": "Networking", "district": "Rubavu", "attendance": 65, "score": 58},
    {"id": "AUCA009", "name": "Grace Uwimana", "age": 20, "gender": "F", "program": "Accounting", "district": "Gasabo", "attendance": 82, "score": 76},
    {"id": "AUCA010", "name": "Yves Ndayisenga", "age": 22, "gender": "M", "program": "Software Engineering", "district": "Nyarugenge", "attendance": 78, "score": 69},
    {"id": "AUCA011", "name": "Josiane Mukeshimana", "age": 21, "gender": "F", "program": "Information Systems", "district": "Muhanga", "attendance": 93, "score": 88},
    {"id": "AUCA012", "name": "Claude Iradukunda", "age": 23, "gender": "M", "program": "Networking", "district": "Gasabo", "attendance": 75, "score": 66},
    {"id": "AUCA013", "name": "Beata Nyirahabimana", "age": 24, "gender": "F", "program": "Accounting", "district": "Nyamagabe", "attendance": 89, "score": 81},
    {"id": "AUCA014", "name": "Olivier Twagirimana", "age": 20, "gender": "M", "program": "Software Engineering", "district": "Kicukiro", "attendance": 96, "score": 90},
    {"id": "AUCA015", "name": "Chantal Uwera", "age": 22, "gender": "F", "program": "Information Systems", "district": "Rusizi", "attendance": 68, "score": 61},
    {"id": "AUCA016", "name": "Fabrice Byiringiro", "age": 21, "gender": "M", "program": "Networking", "district": "Musanze", "attendance": 84, "score": 74},
    {"id": "AUCA017", "name": "Solange Ishimwe", "age": 19, "gender": "F", "program": "Software Engineering", "district": "Gasabo", "attendance": 91, "score": 87},
    {"id": "AUCA018", "name": "David Hakizimana", "age": 25, "gender": "M", "program": "Accounting", "district": "Nyagatare", "attendance": 72, "score": 55},
    {"id": "AUCA019", "name": "Immaculee Uwamahoro", "age": 23, "gender": "F", "program": "Information Systems", "district": "Kicukiro", "attendance": 87, "score": 79},
    {"id": "AUCA020", "name": "Samuel Rukundo", "age": 20, "gender": "M", "program": "Networking", "district": "Nyarugenge", "attendance": 94, "score": 92}
]

print("Dataset loaded successfully.")
# Out:
# Dataset loaded successfully.

# %%
names = [s["name"] for s in students]
all_scores = [s["score"] for s in students]
districts = [s["district"] for s in students]

print(names)
print(all_scores)
print(districts)
# Out:
# ['Aline Uwase', 'Eric Niyonzima', 'Diane Mukamana', 'Jean Bosco Habimana', 'Clarisse Ingabire', 'Patrick Mugisha', 'Sandrine Umutoni', 'Emmanuel Nsengiyumva', 'Grace Uwimana', 'Yves Ndayisenga', 'Josiane Mukeshimana', 'Claude Iradukunda', 'Beata Nyirahabimana', 'Olivier Twagirimana', 'Chantal Uwera', 'Fabrice Byiringiro', 'Solange Ishimwe', 'David Hakizimana', 'Immaculee Uwamahoro', 'Samuel Rukundo']
# [85, 78, 91, 64, 72, 83, 94, 58, 76, 69, 88, 66, 81, 90, 61, 74, 87, 55, 79, 92]
# ['Gasabo', 'Kicukiro', 'Nyarugenge', 'Gasabo', 'Musanze', 'Huye', 'Kicukiro', 'Rubavu', 'Gasabo', 'Nyarugenge', 'Muhanga', 'Gasabo', 'Nyamagabe', 'Kicukiro', 'Rusizi', 'Musanze', 'Gasabo', 'Nyagatare', 'Kicukiro', 'Nyarugenge']

# %%
number_of_students = len(students)
class_average = sum(all_scores) / len(all_scores)
highest_score = max(all_scores)
lowest_score = min(all_scores)
score_range = highest_score - lowest_score

print(f"There are {number_of_students} students in the dataset.")
print(f"The class average score is {round(class_average, 1)}.")
print(f"The highest score is {highest_score}.")
print(f"The lowest score is {lowest_score}.")
print(f"The range is {score_range}.")
# Out:
# There are 20 students in the dataset.
# The class average score is 77.2.
# The highest score is 94.
# The lowest score is 55.
# The range is 39.

# %%
print("First student:", students[0])
print("Last student:", students[-1])
# Out:
# First student: {'id': 'AUCA001', 'name': 'Aline Uwase', 'age': 21, 'gender': 'F', 'program': 'Information Systems', 'district': 'Gasabo', 'attendance': 92, 'score': 85}
# Last student: {'id': 'AUCA020', 'name': 'Samuel Rukundo', 'age': 20, 'gender': 'M', 'program': 'Networking', 'district': 'Nyarugenge', 'attendance': 94, 'score': 92}

# %%
student = students[6]

print(f"{student['name']} from {student['district']} studies {student['program']} and scored {student['score']}.")
# Out:
# Sandrine Umutoni from Kicukiro studies Information Systems and scored 94.

# %%
print("Gasabo:", districts.count("Gasabo"))
print("Kicukiro:", districts.count("Kicukiro"))
print("Nyarugenge:", districts.count("Nyarugenge"))
# Out:
# Gasabo: 5
# Kicukiro: 4
# Nyarugenge: 3

# %%
highest = max(all_scores)
position = all_scores.index(highest)
top_student = names[position]

print(f"The top student is {top_student} with a score of {highest}.")
# Out:
# The top student is Sandrine Umutoni with a score of 94.

# %%
lowest = min(all_scores)
position_lowest = all_scores.index(lowest)
lowest_student = students[position_lowest]

position_highest = all_scores.index(max(all_scores))
highest_student = students[position_highest]

print(f"The top student is {highest_student['name']} with a score of {highest_student['score']} and attendance of {highest_student['attendance']}%.")
print(f"The lowest student is {lowest_student['name']} with a score of {lowest_student['score']} and attendance of {lowest_student['attendance']}%.")
# Out:
# The top student is Sandrine Umutoni with a score of 94 and attendance of 97%.
# The lowest student is David Hakizimana with a score of 55 and attendance of 72%.

# %% [markdown]
# 1. Is this 20-student dataset Big Data? Which of the 5 V's does it clearly not have yet? Explain briefly.
#
# No, this 20-student dataset is not Big Data because it is too small in volume and can easily be stored and processed on a normal computer. It also does not clearly demonstrate the 5 V's of Big Data. In particular, it lacks significant Volume, Velocity, and Variety. The dataset is small, appears to be collected at a normal pace rather than continuously, and mainly contains structured student information.

# %% [markdown]
# 2. Describe one thing from today's session that surprised or confused you.
#
# One thing that surprised me was that numbers can be stored as text in Python. For example, "3" + "4" produces "34" instead of 7 because Python treats them as strings. I learned that type conversion is important when working with real-world datasets because data may not always be stored in the type we expect.

# %% [markdown]
# WEEK 1 LAB REPORT — PYTHON FOUNDATIONS
#
# This week's Introduction to Big Data Analytics lab introduced me to the basic Python concepts needed for data analysis. I created variables using different data types including strings, integers, floats, and Boolean values. I also practiced type conversion by converting a number stored as text into an integer.
#
# I worked with strings and learned how to use f-strings, uppercase conversion, string length, and slicing. I also worked with lists by calculating averages, finding the highest and lowest scores, adding new values, and changing existing values. Dictionaries helped me understand how data can be stored using labeled information such as name, age, program, and district.
#
# For the class dataset, I analyzed records from 20 AUCA students. I calculated the number of students, class average, highest score, lowest score, and score range. I also inspected individual student records and counted students from different districts. The top student in the dataset was Sandrine Umutoni, who scored 94, while the lowest score was 55 by David Hakizimana.
#
# One thing that surprised me was that "3" + "4" produces "34" rather than 7. This helped me understand why knowing the data type is important when working with data. I also learned that a small dataset such as the 20-student dataset used in this lab is not considered Big Data because it does not have the scale and complexity normally associated with Big Data.
