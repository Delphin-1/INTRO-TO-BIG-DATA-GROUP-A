# %%
print("Hello, Big Data!")
# Out:
# Hello, Big Data!

# %%
my_name = "Olivier"
my_age = 26
my_gpa = 3.5
am_i_present = True

print(my_name, type(my_name))
print(my_age, type(my_age))
print(my_gpa, type(my_gpa))
print(am_i_present, type(am_i_present))
# Out:
# Olivier <class 'str'>
# 26 <class 'int'>
# 3.5 <class 'float'>
# True <class 'bool'>

# %%
#Exercise1.2
age_text = "21"

age = int(age_text)
age = age + 1

print(age)
# Out:
# 22

# %%
#question1.3
print("3" + "4")
# Out:
# 34

# %% [markdown]
# Why?Because "3" and "4" are strings, not numbers.Python therefore joins them Whereas: 3 + 4 produces 7

# %%
#Part 2 · Strings — Working with Text exercise 2.1
my_name = "Olivier"
my_age = 26
print(f"I am {my_name}, {my_age} years old, studying at AUCA.")
# Out:
# I am Olivier, 26 years old, studying at AUCA.

# %%
#Exercise 2.2
course = "Big Data Analytics"

print(course.upper())
print(len(course))
print(course[0:3])
# Out:
# BIG DATA ANALYTICS
# 18
# Big

# %%
#Part 3: Lists Exercise 3.1
scores = [72, 85, 91, 64, 78]

print(scores[0])
print(scores[-1])
print(len(scores))
print(sum(scores) / len(scores))
print(max(scores))
print(min(scores))
# Out:
# 72
# 78
# 5
# 78.0
# 91
# 64

# %%
#Exercise 3.2
scores = [72, 85, 91, 64, 78]
scores.append(88)
scores[3] = 66

print(scores)
print(sum(scores) / len(scores))
# Out:
# [72, 85, 91, 66, 78, 88]
# 80.0

# %%
#Part 4 · Dictionaries Exercise 4.1
me = {
    "name": "Olivier",
    "age": 26,
    "program": "Software Engineering",
    "district": "Rubavu"
}

print(me["program"])
# Out:
# Software Engineering

# %%
#Exercise 4.2 — Update and extend
me = {
    "name": "Irembere Olivier",
    "age": 26,
    "program": "Software Engineering",
    "district": "Rubavu"
}
me["score"] = 90

me["age"] = me["age"] + 1

print(me.keys())
print(me)
# Out:
# dict_keys(['name', 'age', 'program', 'district', 'score'])
# {'name': 'Irembere Olivier', 'age': 27, 'program': 'Software Engineering', 'district': 'Rubavu', 'score': 90}

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/week1_students.csv")

df
# Out:
#          ID                  Name  Age Gender               Program  \
# 0   AUCA001           Aline Uwase   21      F   Information Systems
# 1   AUCA002        Eric Niyonzima   23      M  Software Engineering
# 2   AUCA003        Diane Mukamana   20      F   Information Systems
# 3   AUCA004   Jean Bosco Habimana   24      M            Networking
# 4   AUCA005     Clarisse Ingabire   22      F            Accounting
# 5   AUCA006       Patrick Mugisha   21      M  Software Engineering
# 6   AUCA007      Sandrine Umutoni   19      F   Information Systems
# 7   AUCA008  Emmanuel Nsengiyumva   25      M            Networking
# 8   AUCA009         Grace Uwimana   20      F            Accounting
# 9   AUCA010       Yves Ndayisenga   22      M  Software Engineering
# 10  AUCA011   Josiane Mukeshimana   21      F   Information Systems
# 11  AUCA012     Claude Iradukunda   23      M            Networking
# 12  AUCA013   Beata Nyirahabimana   24      F            Accounting
# ...

# %%
#Convert the CSV into the students list
students = df.to_dict("records")

# %%
#Make the column names match the lecturer's Question
df = df.rename(columns={
    "ID": "id",
    "Name": "name",
    "Age": "age",
    "Gender": "gender",
    "Program": "program",
    "District": "district",
    "Att. %": "attendance",
    "Score": "score"
})

# %%
students = df.to_dict("records")

# %%
#checking if it worked
students[0]
# Out:
# {'id': 'AUCA001',
#  'name': 'Aline Uwase',
#  'age': 21,
#  'gender': 'F',
#  'program': 'Information Systems',
#  'district': 'Gasabo',
#  'attendance': 92,
#  'score': 85}

# %%
names = [s["name"] for s in students]
all_scores = [s["score"] for s in students]
districts = [s["district"] for s in students]

# %%
#Exercise 5.1 — Describe the class
print(f"Number of students: {len(students)}")
print(f"Class average score: {round(sum(all_scores) / len(all_scores), 1)}")
print(f"Highest score: {max(all_scores)}")
print(f"Lowest score: {min(all_scores)}")
print(f"Score range: {max(all_scores) - min(all_scores)}")
# Out:
# Number of students: 20
# Class average score: 77.2
# Highest score: 94
# Lowest score: 55
# Score range: 39

# %%
#Exercise 5.2 — Inspect individual records A)First and last student
print("First student:")
print(students[0])

print("Last student:")
print(students[-1])
# Out:
# First student:
# {'id': 'AUCA001', 'name': 'Aline Uwase', 'age': 21, 'gender': 'F', 'program': 'Information Systems', 'district': 'Gasabo', 'attendance': 92, 'score': 85}
# Last student:
# {'id': 'AUCA020', 'name': 'Samuel Rukundo', 'age': 20, 'gender': 'M', 'program': 'Networking', 'district': 'Nyarugenge', 'attendance': 94, 'score': 92}

# %%
#5.2(b) Student at position 6
student = students[6]

print(f"{student['name']} from {student['district']} studies {student['program']} and scored {student['score']}.")
# Out:
# Sandrine Umutoni from Kicukiro studies Information Systems and scored 94.

# %%
#Exercise 5.3 — Count by category
print(f"Students from Gasabo: {districts.count('Gasabo')}")
print(f"Students from Kicukiro: {districts.count('Kicukiro')}")
print(f"Students from Nyarugenge: {districts.count('Nyarugenge')}")
# Out:
# Students from Gasabo: 5
# Students from Kicukiro: 4
# Students from Nyarugenge: 3

# %%
#Exercise 5.4 — checking Who is the top student
highest_score = max(all_scores)
position = all_scores.index(highest_score)
top_student = names[position]

print(f"The top student is {top_student} with a score of {highest_score}.")
# Out:
# The top student is Sandrine Umutoni with a score of 94.

# %%
#Bonus — Lowest student + attendance
lowest_score = min(all_scores)
lowest_position = all_scores.index(lowest_score)
lowest_student = students[lowest_position]

highest_score = max(all_scores)
highest_position = all_scores.index(highest_score)
highest_student = students[highest_position]

print(f"The top student is {highest_student['name']} with a score of {highest_student['score']} and attendance of {highest_student['attendance']}%.")
print(f"The lowest student is {lowest_student['name']} with a score of {lowest_student['score']} and attendance of {lowest_student['attendance']}%.")
# Out:
# The top student is Sandrine Umutoni with a score of 94 and attendance of 97%.
# The lowest student is David Hakizimana with a score of 55 and attendance of 72%.

# %% [markdown]
# # **Part 6 · Reflection (required, checked for completion)**
#
# **1. Is this 20-student dataset Big Data? Which of the 5 V's does it clearly not have yet? Explain briefly**
#
# No, this 20-student dataset is not Big Data. It is a small dataset because it contains only 20 records and can easily be stored, processed, and analyzed using a normal computer and Python.
#
# The 5 V's of Big Data are **Volume**, **Velocity, Variety, Veracity,** and **Value**. This dataset clearly does not have **Volume**, because 20 student records are far too small to represent a large amount of data. It also does not clearly demonstrate **Velocity**, because the data is static rather than being generated or updated continuously at high speed. It has a simple and consistent structure, so it also has very little **Variety** compared with real Big Data, which may contain text, images, videos, sensor data, and other formats.
#
# Therefore, this dataset is useful for learning data analysis, but it is not Big Data because it lacks the large scale and complexity normally associated with Big Data.
#
#
# **2. Describe one thing from today's session that surprised or confused you**
#
#
# One thing that surprised me during today's session was how we used a CSV file and converted its data into a form that could be easily used and analyzed by Python in Google Colab. I was also surprised by how easily Python can manipulate data, such as selecting specific information, calculating averages, finding the highest and lowest scores, and organizing data using lists and dictionaries. As someone studying Python for the first time, I found it interesting that a small amount of code can perform operations on many records at once. I was also surprised by how lists, dictionaries, and functions can work together to make data analysis easier. This helped me understand that Python is not only used for writing programs but can also be very useful for working with and analyzing real-world data.
