# %%
## Part 0 · Warm-Up

print("Hello, BigData!")
# Out:
# Hello, BigData!

# %%
## Part 1 · Variables & Data Types 

my_name = "JOHNSON"
my_age = 24
my_gpa = 3.4
am_i_present = True 

print(my_name ,type(my_name))
print(my_age ,type(my_age))
print(my_gpa ,type(my_gpa))
print(am_i_present ,type(am_i_present))
# Out:
# JOHNSON <class 'str'>
# 24 <class 'int'>
# 3.4 <class 'float'>
# True <class 'bool'>

# %%
##  Exercise 1.2 — Type conversion

age_text = "50"
age = int(age_text)
age = age + 1
print(age)
# Out:
# 51

# %%
## Question 1.3 — Think about it 

print("3" + "4")
## This will display 34 , Because they are all a string (text) and + operator is going to join instead of adding them as a number
# Out:
# 34

# %%
## Part 2 · Strings — Working with Text
## Exercise 2.1 — f-strings

my_name = "johnson"
my_age = 24

print (f"Hello My name is {my_name}, {my_age} years old, studying at AUCA.")
# Out:
# Hello My name is johnson, 24 years old, studying at AUCA.

# %%
## Exercise 2.2 — String tools

course = "Big Data Analytics"
to_upper = course.upper()
length = len(course)
sub_string = course[0:3]

print (f"Course_Name :{to_upper}")
print (f"lenght :{length}")
print (f"Sub_String :{sub_string}")
# Out:
# Course_Name :BIG DATA ANALYTICS
# lenght :18
# Sub_String :Big

# %%
## Exercise 3.1 

scores = [72, 85, 91, 64, 78]
first_number = scores[0]
last_number = scores[-1]
list_length = len(scores)
total = sum(scores)
avg = total / list_length
max_score = max(scores)
min_score = min(scores)

print (f"first_score : {first_number}")
print (f"last_score : {last_number}")
print (f"List_length : {list_length}")
print (f"total : {total}")
print (f" Average : {avg}")
print (f" max_score : {max_score}")
print (f" min_score : {min_score}")
# Out:
# first_score : 72
# last_score : 78
# List_length : 5
# total : 390
#  Average : 78.0
#  max_score : 91
#  min_score : 64

# %%
## Exercise 3.2 — Lists change

new_scores = scores.append(88)
scores[3] = 66

new_length = len(scores)
new_total = sum(scores)
new_avg = new_total / new_length 

print (f"new_scores : {scores}")
print (f"new_avg : {new_avg}")
# Out:
# new_scores : [72, 85, 91, 66, 78, 88]
# new_avg : 80.0

# %%
##  Part 4 · Dictionaries — Labeled Data 
## Exercise 4.1

me = {
    "name": "johnson",
    "age": 24,
    "program": "Software Engineering",
    "district": "GASABO"
}

print(me["program"])
# Out:
# Software Engineering

# %%
## Exercise 4.2 — Update and extend 
## adding score 

me["score"] = 87
me["age"] = me["age"] +2
properties = me.keys()

print (f"Properties: {properties}")
print (f"New_dic: {me}")
# Out:
# Properties: dict_keys(['name', 'age', 'program', 'district', 'score'])
# New_dic: {'name': 'johnson', 'age': 26, 'program': 'Software Engineering', 'district': 'GASABO', 'score': 87}

# %%
  ## Part 5 · Class Dataset Analysis 


import pandas as pd

df = pd.read_excel("week1_students.xlsx")
df
# Out:
#    student_id                  name  age gender               program  \
# 0     AUCA001           Aline Uwase   21      F   Information Systems
# 1     AUCA002        Eric Niyonzima   23      M  Software Engineering
# 2     AUCA003        Diane Mukamana   20      F   Information Systems
# 3     AUCA004   Jean Bosco Habimana   24      M            Networking
# 4     AUCA005     Clarisse Ingabire   22      F            Accounting
# 5     AUCA006       Patrick Mugisha   21      M  Software Engineering
# 6     AUCA007      Sandrine Umutoni   19      F   Information Systems
# 7     AUCA008  Emmanuel Nsengiyumva   25      M            Networking
# 8     AUCA009         Grace Uwimana   20      F            Accounting
# 9     AUCA010       Yves Ndayisenga   22      M  Software Engineering
# 10    AUCA011   Josiane Mukeshimana   21      F   Information Systems
# 11    AUCA012     Claude Iradukunda   23      M            Networking
# 12    AUCA013   Beata Nyirahabimana   24      F            Accounting
# 13    AUCA014   Olivier Twagirimana   20      M  Software Engineering
# 14    AUCA015         Chantal Uwera   22      F   Information Systems
# 15    AUCA016    Fabrice Byiringiro   21      M            Networking
# 16    AUCA017       Solange Ishimwe   19      F  Software Engineering
# 17    AUCA018      David Hakizimana   25      M            Accounting
# 18    AUCA019   Immaculee Uwamahoro   23      F   Information Systems
# 19    AUCA020        Samuel Rukundo   20      M            Networking
#
#       district  attendance_pct  score
# 0       Gasabo              92     85
# 1     Kicukiro              88     78
# 2   Nyarugenge              95     91
# 3       Gasabo              70     64
# 4      Musanze              85     72
# 5         Huye              90     83
# 6     Kicukiro              97     94
# 7       Rubavu              65     58
# 8       Gasabo              82     76
# 9   Nyarugenge              78     69
# 10     Muhanga              93     88
# 11      Gasabo              75     66
# 12   Nyamagabe              89     81
# 13    Kicukiro              96     90
# 14      Rusizi              68     61
# 15     Musanze              84     74
# 16      Gasabo              91     87
# 17   Nyagatare              72     55
# 18    Kicukiro              87     79
# 19  Nyarugenge              94     92

# %%
students = df.to_dict ("records")
students
# Out:
# [{'student_id': 'AUCA001',
#   'name': 'Aline Uwase',
#   'age': 21,
#   'gender': 'F',
#   'program': 'Information Systems',
#   'district': 'Gasabo',
#   'attendance_pct': 92,
#   'score': 85},
#  {'student_id': 'AUCA002',
#   'name': 'Eric Niyonzima',
#   'age': 23,
#   'gender': 'M',
#   'program': 'Software Engineering',
#   'district': 'Kicukiro',
#   'attendance_pct': 88,
#   'score': 78},
#  {'student_id': 'AUCA003',
#   'name': 'Diane Mukamana',
#   'age': 20,
#   'gender': 'F',
#   'program': 'Information Systems',
#   'district': 'Nyarugenge',
#   'attendance_pct': 95,
#   'score': 91},
#  {'student_id': 'AUCA004',
#   'name': 'Jean Bosco Habimana',
#   'age': 24,
#   'gender': 'M',
#   'program': 'Networking',
#   'district': 'Gasabo',
#   'attendance_pct': 70,
#   'score': 64},
#  {'student_id': 'AUCA005',
#   'name': 'Clarisse Ingabire',
#   'age': 22,
#   'gender': 'F',
#   'program': 'Accounting',
#   'district': 'Musanze',
#   'attendance_pct': 85,
#   'score': 72},
#  {'student_id': 'AUCA006',
#   'name': 'Patrick Mugisha',
#   'age': 21,
#   'gender': 'M',
#   'program': 'Software Engineering',
#   'district': 'Huye',
#   'attendance_pct': 90,
#   'score': 83},
#  {'student_id': 'AUCA007',
#   'name': 'Sandrine Umutoni',
#   'age': 19,
#   'gender': 'F',
#   'program': 'Information Systems',
#   'district': 'Kicukiro',
#   'attendance_pct': 97,
#   'score': 94},
#  {'student_id': 'AUCA008',
#   'name': 'Emmanuel Nsengiyumva',
#   'age': 25,
#   'gender': 'M',
#   'program': 'Networking',
#   'district': 'Rubavu',
#   'attendance_pct': 65,
#   'score': 58},
#  {'student_id': 'AUCA009',
#   'name': 'Grace Uwimana',
#   'age': 20,
#   'gender': 'F',
#   'program': 'Accounting',
#   'district': 'Gasabo',
#   'attendance_pct': 82,
#   'score': 76},
#  {'student_id': 'AUCA010',
#   'name': 'Yves Ndayisenga',
#   'age': 22,
#   'gender': 'M',
#   'program': 'Software Engineering',
#   'district': 'Nyarugenge',
#   'attendance_pct': 78,
#   'score': 69},
#  {'student_id': 'AUCA011',
#   'name': 'Josiane Mukeshimana',
#   'age': 21,
#   'gender': 'F',
#   'program': 'Information Systems',
#   'district': 'Muhanga',
#   'attendance_pct': 93,
#   'score': 88},
#  {'student_id': 'AUCA012',
#   'name': 'Claude Iradukunda',
#   'age': 23,
#   'gender': 'M',
#   'program': 'Networking',
#   'district': 'Gasabo',
#   'attendance_pct': 75,
#   'score': 66},
#  {'student_id': 'AUCA013',
#   'name': 'Beata Nyirahabimana',
#   'age': 24,
#   'gender': 'F',
#   'program': 'Accounting',
#   'district': 'Nyamagabe',
#   'attendance_pct': 89,
#   'score': 81},
#  {'student_id': 'AUCA014',
#   'name': 'Olivier Twagirimana',
#   'age': 20,
#   'gender': 'M',
#   'program': 'Software Engineering',
#   'district': 'Kicukiro',
#   'attendance_pct': 96,
#   'score': 90},
#  {'student_id': 'AUCA015',
#   'name': 'Chantal Uwera',
#   'age': 22,
#   'gender': 'F',
#   'program': 'Information Systems',
#   'district': 'Rusizi',
#   'attendance_pct': 68,
#   'score': 61},
#  {'student_id': 'AUCA016',
#   'name': 'Fabrice Byiringiro',
#   'age': 21,
#   'gender': 'M',
#   'program': 'Networking',
#   'district': 'Musanze',
#   'attendance_pct': 84,
#   'score': 74},
#  {'student_id': 'AUCA017',
#   'name': 'Solange Ishimwe',
#   'age': 19,
#   'gender': 'F',
#   'program': 'Software Engineering',
#   'district': 'Gasabo',
#   'attendance_pct': 91,
#   'score': 87},
#  {'student_id': 'AUCA018',
#   'name': 'David Hakizimana',
#   'age': 25,
#   'gender': 'M',
#   'program': 'Accounting',
#   'district': 'Nyagatare',
#   'attendance_pct': 72,
#   'score': 55},
#  {'student_id': 'AUCA019',
#   'name': 'Immaculee Uwamahoro',
#   'age': 23,
#   'gender': 'F',
#   'program': 'Information Systems',
#   'district': 'Kicukiro',
#   'attendance_pct': 87,
#   'score': 79},
#  {'student_id': 'AUCA020',
#   'name': 'Samuel Rukundo',
#   'age': 20,
#   'gender': 'M',
#   'program': 'Networking',
#   'district': 'Nyarugenge',
#   'attendance_pct': 94,
#   'score': 92}]

# %%
 ## Exercise 5.1 — Describe the class 

scores = [student["score"] for student in students]

print (f"Number of students :{len(students)}")
print (f"Class average :{round(sum(scores)/len(scores)),1}")
print (f"Highest score :{max(scores)}")
print (f"Lowest score :{min(scores)}")
print (f"Score_Range :{max(scores) - min(scores)}")
# Out:
# Number of students :20
# Class average :(77, 1)
# Highest score :94
# Lowest score :55
# Score_Range :39

# %%
## Exercise 5.2 — Inspect individual records

print (f"First_student : {students[0]}")
print (f"Last_student : {students[-1]}")
# Out:
# First_student : {'student_id': 'AUCA001', 'name': 'Aline Uwase', 'age': 21, 'gender': 'F', 'program': 'Information Systems', 'district': 'Gasabo', 'attendance_pct': 92, 'score': 85}
# Last_student : {'student_id': 'AUCA020', 'name': 'Samuel Rukundo', 'age': 20, 'gender': 'M', 'program': 'Networking', 'district': 'Nyarugenge', 'attendance_pct': 94, 'score': 92}

# %%
##  Exercise 5.3 — Count by category

student = students[6]

print(f"{student["name"]} from {student["district"]} studies {student["program"]} and scored {student["score"]}.")
# Out:
# Sandrine Umutoni from Kicukiro studies Information Systems and scored 94.

# %%
 ## Exercise 5.3 — Count by category

districts = [student["district"] for student in students]
print(districts)

print(f"Gasabo : {districts.count("Gasabo")}")
print(f"Kicukiro : {districts.count("Kicukiro")}")
print(f"Gasabo : {districts.count("Nyarugenge")}")
# Out:
# ['Gasabo', 'Kicukiro', 'Nyarugenge', 'Gasabo', 'Musanze', 'Huye', 'Kicukiro', 'Rubavu', 'Gasabo', 'Nyarugenge', 'Muhanga', 'Gasabo', 'Nyamagabe', 'Kicukiro', 'Rusizi', 'Musanze', 'Gasabo', 'Nyagatare', 'Kicukiro', 'Nyarugenge']
# Gasabo : 5
# Kicukiro : 4
# Gasabo : 3

# %%
## Exercise 5.4 — Stretch goal: who is the top student?

names = [student["name"] for student in students]

best_score = max(scores)
position = scores.index(best_score)
best_name = names[position]

print(f"The best student is {best_name} with a score of {best_score}.");
# Out:
# The best student is Sandrine Umutoni with a score of 94.

# %%
## strech

attendances = [student["attendance_pct"] for student in students]

lowest_score = min(scores)
position = scores.index(lowest_score)
lowest_name = names[position]

print(f"The lowest student is {lowest_name} with a score of {lowest_score} and attendance of {attendances[position]}%.")
# Out:
# The lowest student is David Hakizimana with a score of 55 and attendance of 72%.

# %%
## Part 6 · Reflection 


# Q1. Is this 20-student dataset Big Data?

    # Ans:  No. It is a small dataset, not Big Data. It has only 20 student records, so it is easy to store and analyze.
    #   The 5 V’s of Big Data are Volume, Velocity, Variety, Veracity, and Value. This dataset clearly does not have enough Volume because there are only 20 students. It also has limited Velocity because the data is not being generated or updated continuously in real time.

# Q2. Something that surprised or confused me:

      # Ans: One thing that surprised me was that Python treats numbers and text differently. For example, "3" + "4" gives "34" instead of 7 because they are strings. I found it interesting that Python's result depends on the data type.
