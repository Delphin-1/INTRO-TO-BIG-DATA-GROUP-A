# %%
print('hello big data')
# Out:
# hello big data

# %%
my_name = "Ines"
my_age = 21
my_gpa = 3.5
am_i_present = True

print(my_name, type(my_name))
print(my_age, type(my_age))
print(my_gpa, type(my_gpa))
print(am_i_present, type(am_i_present))
# Out:
# Ines <class 'str'>
# 21 <class 'int'>
# 3.5 <class 'float'>
# True <class 'bool'>

# %%
age_text = "21"

# %%
age_text = "21"

age = int(age_text)
age = age + 1

print(age)
# Out:
# 22

# %%
print("3" + "4")
# Out:
# 34

# %%
print(f"I am {my_name}, {my_age} years old, studying at AUCA.")
# Out:
# I am Ines, 21 years old, studying at AUCA.

# %%
f"Hello {my_name}"
# Out:
# 'Hello Ines'

# %%
course = "Big Data Analytics"

print(course.upper())
print(len(course))
print(course[0:3])
# Out:
# BIG DATA ANALYTICS
# 18
# Big

# %%
course.upper()
# Out:
# 'BIG DATA ANALYTICS'

# %%
len(course)
# Out:
# 18

# %%
course[0:3]
# Out:
# 'Big'

# %%
scores = [72, 85, 91, 64, 78]

# %%
scores = [72, 85, 91, 64, 78]

print("First score:", scores[0])
print("Last score:", scores[-1])
print("Number of scores:", len(scores))
print("Average:", sum(scores) / len(scores))
print("Highest score:", max(scores))
print("Lowest score:", min(scores))
# Out:
# First score: 72
# Last score: 78
# Number of scores: 5
# Average: 78.0
# Highest score: 91
# Lowest score: 64

# %%
scores.append(88)
scores[3] = 66

print("Updated list:", scores)
print("New average:", sum(scores) / len(scores))
# Out:
# Updated list: [72, 85, 91, 66, 78, 88]
# New average: 80.0

# %%
me = {
    "name": "Ines",
    "age": 21,
    "program": "Computer Science",
    "district": "Gasabo"
}

print(me["program"])
# Out:
# Computer Science

# %%
me["score"] = 90
me["age"] = me["age"] + 1

print(me.keys())
print(me)
# Out:
# dict_keys(['name', 'age', 'program', 'district', 'score'])
# {'name': 'Ines', 'age': 22, 'program': 'Computer Science', 'district': 'Gasabo', 'score': 90}
