# %% [markdown]
# # Week 1 Lab — Python Foundations**Name:** Sultan Ray  **Student ID:** 28214  **Program:** Information Systems

# %% [markdown]
# ## Part 0 · Warm-Up

# %%
print("Hello, Big Data!")
# Out:
# Hello, Big Data!

# %% [markdown]
# ## Part 1 · Variables & Data Types

# %% [markdown]
# ### Exercise 1.1 — Personal variables

# %%
#variable and datatype part

my_name = "Sultan Ray"
my_age = 25
my_gpa = 3.6
am_i_present = True

print(my_name, type(my_name))
print(my_age, type(my_age))
print(my_gpa, type(my_gpa))
print(am_i_present, type(am_i_present))
# Out:
# Sultan Ray <class 'str'>
# 25 <class 'int'>
# 3.6 <class 'float'>
# True <class 'bool'>

# %% [markdown]
# ### Exercise 1.2 — Type conversion

# %%
#converting text to numbers

age_text = "25"
age_number = int(age_text) + 1
print(age_number)
# Out:
# 26

# %% [markdown]
# ### Question 1.3 — Think about it

# %%
"3"+"4"
#the result shork me i throught  it will 7 but this is concantination
# Out:
# '34'

# %% [markdown]
# ## Part 2 · Strings

# %% [markdown]
# ### Exercise 2.1 — f-strings

# %%
#Strings part

print(f"I am {my_name}, {my_age} years old, studying at AUCA.")
# Out:
# I am Sultan Ray, 25 years old, studying at AUCA.

# %% [markdown]
# ### Exercise 2.2 — String tools

# %%
course = "Big Data Analytics"
print(course.upper())      # (a) uppercase
print(len(course))         # (b) number of characters
print(course[0:3])         # (c) first 3 characters
# Out:
# BIG DATA ANALYTICS
# 18
# Big

# %% [markdown]
# ## Part 3 · Lists

# %% [markdown]
# ### Exercise 3.1

# %%
#list part
scores = [72, 85, 91, 64, 78]
print(scores[0], scores[-1])          # first and last
print(len(scores))                     # count
print(sum(scores)/len(scores))         # average
print(max(scores), min(scores))        # highest, lowest
# Out:
# 72 78
# 5
# 78.0
# 91 64

# %% [markdown]
# ### Exercise 3.2 — Lists change

# %%
scores.append(88)        # (a) add new member
scores[3] = 66            # (b) fix the 4th score
print(scores)             # (c) updated list
print(sum(scores)/len(scores))   # new average
# Out:
# [72, 85, 91, 66, 78, 88]
# 80.0

# %% [markdown]
# ## Part 4 · Dictionaries

# %% [markdown]
# ### Exercise 4.1

# %%
#Dictionaly
me = {"name": "Sultan Ray", "age": 25, "program": "Information Systems", "district": "Gasabo"}
print(me["program"])
# Out:
# Information Systems

# %% [markdown]
# ### Exercise 4.2 — Update and extend

# %%
me["score"] = 85          # (a) add new key
me["age"] += 1             # (b) increase age
print(me.keys())          # (c) all keys
print(me)                 # whole dictionary
# Out:
# dict_keys(['name', 'age', 'program', 'district', 'score'])
# {'name': 'Sultan Ray', 'age': 26, 'program': 'Information Systems', 'district': 'Gasabo', 'score': 85}

# %% [markdown]
# ## Part 5 · Class Dataset Analysis

# %% [markdown]
# Building the class dataset — 20 AUCA students.

# %%
students = [
    {"id": "AUCA001", "name": "Aline Uwase", "age": 21, "gender": "F", "program": "Information Systems", "district": "Gasabo", "attendance": 92, "score": 85},
    {"id": "AUCA002", "name": "Eric Niyonzima", "age": 23, "gender": "M", "program": "Software Engineering", "district": "Kicukiro", "attendance": 88, "score": 78},
    {"id": "AUCA003", "name": "Diane Mukamana", "age": 20, "gender": "F", "program": "Information Systems", "district": "Nyarugenge", "attendance": 95, "score": 91},
    {"id": "AUCA004", "name": "Jean Bosco Habimana", "age": 24, "gender": "M", "program": "Networking", "district": "Gasabo", "attendance": 70, "score": 64},
    {"id": "AUCA005", "name": "Clarisse Ingabire", "age": 22, "gender": "F", "program": "Accounting", "district": "Musanze", "attendance": 85, "score": 72},
    {"id": "AUCA006", "name": "Patrick Mugisha", "age": 21, "gender": "M", "program": "Software Engineering", "district": "Huye", "attendance": 90, "score": 83},
    {"id": "AUCA007", "name": "Sandrine Umutoni", "age": 19, "gender": "F", "program": "Information Systems", "district": "Kicukiro", "attendance": 97, "score": 94},
    {"id": "AUCA008", "name": "Emmanuel Nsengiyumva", "age": 25, "gender": "M", "program": "Networking", "district": "Rubavu", "attendance": 65, "score": 58},
    {"id": "AUCA009", "name": "Grace Uwimana", "age": 20, "gender": "F", "program": "Accounting", "district": "Gasabo", "attendance": 82, "score": 76},
    {"id": "AUCA010", "name": "Yves Ndayisenga", "age": 22, "gender": "M", "program": "Software Engineering", "district": "Nyarugenge", "attendance": 78, "score": 69},
    {"id": "AUCA011", "name": "Josiane Mukeshimana", "age": 21, "gender": "F", "program": "Information Systems", "district": "Muhanga", "attendance": 93, "score": 88},
    {"id": "AUCA012", "name": "Claude Iradukunda", "age": 23, "gender": "M", "program": "Networking", "district": "Gasabo", "attendance": 75, "score": 66},
    {"id": "AUCA013", "name": "Beata Nyirahabimana", "age": 24, "gender": "F", "program": "Accounting", "district": "Nyamagabe", "attendance": 89, "score": 81},
    {"id": "AUCA014", "name": "Olivier Twagirimana", "age": 20, "gender": "M", "program": "Software Engineering", "district": "Kicukiro", "attendance": 96, "score": 90},
    {"id": "AUCA015", "name": "Chantal Uwera", "age": 22, "gender": "F", "program": "Information Systems", "district": "Rusizi", "attendance": 68, "score": 61},
    {"id": "AUCA016", "name": "Fabrice Byiringiro", "age": 21, "gender": "M", "program": "Networking", "district": "Musanze", "attendance": 84, "score": 74},
    {"id": "AUCA017", "name": "Solange Ishimwe", "age": 19, "gender": "F", "program": "Software Engineering", "district": "Gasabo", "attendance": 91, "score": 87},
    {"id": "AUCA018", "name": "David Hakizimana", "age": 25, "gender": "M", "program": "Accounting", "district": "Nyagatare", "attendance": 72, "score": 55},
    {"id": "AUCA019", "name": "Immaculee Uwamahoro", "age": 23, "gender": "F", "program": "Information Systems", "district": "Kicukiro", "attendance": 87, "score": 79},
    {"id": "AUCA020", "name": "Samuel Rukundo", "age": 20, "gender": "M", "program": "Networking", "district": "Nyarugenge", "attendance": 94, "score": 92},
]

# %% [markdown]
# Ready-made column lists.

# %%
names = [s["name"] for s in students]
all_scores = [s["score"] for s in students]
districts = [s["district"] for s in students]

# %% [markdown]
# ### Exercise 5.1 — Describe the class

# %%
print(f"Number of students: {len(students)}")
print(f"Class average score: {round(sum(all_scores)/len(all_scores), 1)}")
print(f"Highest: {max(all_scores)}, Lowest: {min(all_scores)}")
print(f"Range: {max(all_scores) - min(all_scores)}")
# Out:
# Number of students: 20
# Class average score: 77.2
# Highest: 94, Lowest: 55
# Range: 39

# %% [markdown]
# ### Exercise 5.2 — Inspect individual records

# %%
print(students[0])         # first student's full record
print(students[-1])        # last student's full record

s = students[6]  # position 6 = 7th student
print(f"{s['name']} from {s['district']} studies {s['program']} and scored {s['score']}.")
# Out:
# {'id': 'AUCA001', 'name': 'Aline Uwase', 'age': 21, 'gender': 'F', 'program': 'Information Systems', 'district': 'Gasabo', 'attendance': 92, 'score': 85}
# {'id': 'AUCA020', 'name': 'Samuel Rukundo', 'age': 20, 'gender': 'M', 'program': 'Networking', 'district': 'Nyarugenge', 'attendance': 94, 'score': 92}
# Sandrine Umutoni from Kicukiro studies Information Systems and scored 94.

# %% [markdown]
# ### Exercise 5.3 — Count by category

# %%
print(districts.count("Gasabo"))
print(districts.count("Kicukiro"))
print(districts.count("Musanze"))
# Out:
# 5
# 4
# 2

# %% [markdown]
# ### Exercise 5.4 — Stretch goal: who is the top student?

# %%
top_score = max(all_scores)
top_position = all_scores.index(top_score)
top_name = names[top_position]
print(f"The top student is {top_name} with a score of {top_score}.")
# Out:
# The top student is Sandrine Umutoni with a score of 94.

# %% [markdown]
# ## Part 6 · Reflection**1. Is this 20-student dataset Big Data? Which of the 5 V's does it clearly not have yet?**This dataset is not Big Data. It only contains 20 records, so it clearly lacks **Volume** — one of the core 5 V's(Volume, Velocity, Variety, Veracity, Value). Big Data usually refers to datasets so large that they can't be opened,viewed, or processed with everyday tools like Excel, whereas this entire table can be scrolled through and read inseconds. It's also missing **Velocity**, since it's a single static file rather than data continuously streaming inreal time (like sensor readings or social media posts). To be considered Big Data, this dataset would need to scaleup to thousands or millions of student records collected continuously over time.**2. Describe one thing from today's session that surprised or confused you.**The thing that surprised me most was Question 1.3, where `"3" + "4"` produced `"34"` instead of `7`. I expectedPython to add the numbers together, but because both values were stored as strings (text), the `+` operatorconcatenated them instead of performing math. This was a good reminder that data type matters a lot when workingwith real datasets, since numbers stored as text won't behave the way I expect until I explicitly convert them with`int()` or `float()`.

# %% [markdown]
# ## ✓ Submission checklist- [x] Notebook renamed to `Week1_YourName`- [x] All exercises run without errors- [x] Reflection answered- [ ] Screenshots of running code- [x] ½–1 page report- [ ] Submitted before the end of Week 1
