# %%
my_name = "Hakizimana Honore Patient"
my_age = 22
my_gpa = 15.5
am_i_present = True

print(my_name, type(my_name))
print(my_age, type(my_age))
print(my_gpa, type(my_gpa))
print(am_i_present, type(am_i_present))
# Out:
# Hakizimana Honore Patient <class 'str'>
# 22 <class 'int'>
# 15.5 <class 'float'>
# True <class 'bool'>

# %%
age_text = "22"
age = int(age_text)
print(age + 1)
# Out:
# 23

# %%
print("3" + "4")
# Out:
# 34

# %%
print(f"I am {my_name}, {my_age} years old, studying at AUCA.")
# Out:
# I am Hakizimana Honore Patient, 22 years old, studying at AUCA.

# %%
course = "Big Data Analytics"

print(course.upper())
print(len(course))
print(course[0:3])
# Out:
# BIG DATA ANALYTICS
# 18
# Big

# %%
scores = [72, 85, 91, 64, 78]

print("First score:", scores[0])
print("Last score:", scores[-1])
print("Number of scores:", len(scores))
print("Average:", sum(scores) / len(scores))
print("Highest score:", max(scores))
print("Lowest score:", min(scores))
# Out:
# First score: 72
# Last score: 78
# Number of scores: 5
# Average: 78.0
# Highest score: 91
# Lowest score: 64

# %%
scores.append(88)
scores[3] = 66

print(scores)
print("New average:", sum(scores) / len(scores))
# Out:
# [72, 85, 91, 66, 78, 88]
# New average: 80.0

# %%
me = {
    "name": "Hakizimana Honore Patient",
    "age": 22,
    "program": "Law",
    "district": "Muhanga"
}

print(me["program"])
# Out:
# Law

# %%
me["score"] = 85
me["age"] = me["age"] + 1

print(me.keys())
print(me)
# Out:
# dict_keys(['name', 'age', 'program', 'district', 'score'])
# {'name': 'Hakizimana Honore Patient', 'age': 23, 'program': 'Law', 'district': 'Muhanga', 'score': 85}
